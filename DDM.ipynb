# %%
import pandas as pd
import numpy as np
import matplotlib as plt
import os
import sys
import json
import csv

# %%
# os.getcwd()
def read_json_file(file_path):
    try:
        with open(file_path, 'r') as file:
            data = json.load(file)
            return data
    except FileNotFoundError:
        print(f"Error: File not found at path {file_path}")
        return None
    except json.JSONDecodeError:
        print(f"Error: Unable to decode JSON from file {file_path}")
        return None

# %%
overview = read_json_file("overview_IBM.json")

# %%
import re

daily_stock_prices = read_json_file("daily_adjusted_full_IBM.json")

dividends = read_json_file("cash_flow_IBM.json")["quarterlyReports"]
dividends

# {dividends[0]['fiscalDateEnding']:dividends[0]['dividendPayout']}
# Out:
# [{'fiscalDateEnding': '2023-09-30',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '3056000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1093000000',
#   'capitalExpenditures': '281000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': 'None',
#   'profitLoss': '1714000000',
#   'cashflowFromInvestment': '-1953000000',
#   'cashflowFromFinancing': '-3132000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '9000000',
#   'paymentsForRepurchaseOfCommonStock': 'None',
#   'paymentsForRepurchaseOfEquity': 'None',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1515000000',
#   'dividendPayoutCommonStock': '1515000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '154000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '-98000000',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': 'None',
#   'changeInExchangeRate': 'None',
#   'netIncome': '1704000000'},
#  {'fiscalDateEnding': '2023-06-30',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '2638000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1077000000',
#   'capitalExpenditures': '364000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': 'None',
#   'profitLoss': '1581000000',
#   'cashflowFromInvestment': '7000000',
#   'cashflowFromFinancing': '-2730000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '0',
#   'paymentsForRepurchaseOfCommonStock': '0',
#   'paymentsForRepurchaseOfEquity': '0',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1510000000',
#   'dividendPayoutCommonStock': '1510000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '0',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '0',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '-85000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '1583000000'},
#  {'fiscalDateEnding': '2023-03-31',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '3774000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1074000000',
#   'capitalExpenditures': '300000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': 'None',
#   'profitLoss': '927000000',
#   'cashflowFromInvestment': '-7960000000',
#   'cashflowFromFinancing': '5708000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '-3000000',
#   'paymentsForRepurchaseOfCommonStock': '0',
#   'paymentsForRepurchaseOfEquity': '0',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1497000000',
#   'dividendPayoutCommonStock': '1497000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '9432000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '0',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '1522000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '927000000'},
#  {'fiscalDateEnding': '2022-12-31',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '3965000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1137000000',
#   'capitalExpenditures': '409000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': '71000000',
#   'profitLoss': '2710000000',
#   'cashflowFromInvestment': '-1319000000',
#   'cashflowFromFinancing': '-2852000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '-4000000',
#   'paymentsForRepurchaseOfCommonStock': '0',
#   'paymentsForRepurchaseOfEquity': '0',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1494000000',
#   'dividendPayoutCommonStock': '1494000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '7000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '0',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': 'None',
#   'changeInExchangeRate': 'None',
#   'netIncome': '2710000000'},
#  {'fiscalDateEnding': '2022-09-30',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '1901000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1163000000',
#   'capitalExpenditures': '317000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': '71000000',
#   'profitLoss': '-3196000000',
#   'cashflowFromInvestment': '-1697000000',
#   'cashflowFromFinancing': '713000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '230000000',
#   'paymentsForRepurchaseOfCommonStock': '0',
#   'paymentsForRepurchaseOfEquity': '0',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1491000000',
#   'dividendPayoutCommonStock': '1491000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '3395000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '0',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '917000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '-3196000000'},
#  {'fiscalDateEnding': '2022-06-30',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '1321000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1246000000',
#   'capitalExpenditures': '339000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': 'None',
#   'profitLoss': '1392000000',
#   'cashflowFromInvestment': '172000000',
#   'cashflowFromFinancing': '-4196000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '-1000000',
#   'paymentsForRepurchaseOfCommonStock': '0',
#   'paymentsForRepurchaseOfEquity': '0',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1488000000',
#   'dividendPayoutCommonStock': '1488000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '318000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '0',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '-2703000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '1392000000'},
#  {'fiscalDateEnding': '2022-03-31',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '3248000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1256000000',
#   'capitalExpenditures': '281000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': 'None',
#   'profitLoss': '733000000',
#   'cashflowFromInvestment': '-1358000000',
#   'cashflowFromFinancing': '1377000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '-8000000',
#   'paymentsForRepurchaseOfCommonStock': '0',
#   'paymentsForRepurchaseOfEquity': '0',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1475000000',
#   'dividendPayoutCommonStock': '1475000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '4084000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '0',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '3267000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '733000000'},
#  {'fiscalDateEnding': '2021-12-31',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '2544000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1381000000',
#   'capitalExpenditures': '450000000',
#   'changeInReceivables': '1372000000',
#   'changeInInventory': '138000000',
#   'profitLoss': '2333000000',
#   'cashflowFromInvestment': '-675000000',
#   'cashflowFromFinancing': '-2692000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '-880000000',
#   'paymentsForRepurchaseOfCommonStock': '0',
#   'paymentsForRepurchaseOfEquity': '0',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1474000000',
#   'dividendPayoutCommonStock': '1474000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '128000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '0',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '-823000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '2333000000'},
#  {'fiscalDateEnding': '2021-09-30',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '2713000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1684000000',
#   'capitalExpenditures': '558000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': '138000000',
#   'profitLoss': '1130000000',
#   'cashflowFromInvestment': '-629000000',
#   'cashflowFromFinancing': '-1748000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '908000000',
#   'paymentsForRepurchaseOfCommonStock': '0',
#   'paymentsForRepurchaseOfEquity': '0',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1471000000',
#   'dividendPayoutCommonStock': '1471000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '151000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '0',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '1130000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '1130000000'},
#  {'fiscalDateEnding': '2021-06-30',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '2625000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1680000000',
#   'capitalExpenditures': '560000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': '138000000',
#   'profitLoss': '1325000000',
#   'cashflowFromInvestment': '-2671000000',
#   'cashflowFromFinancing': '-3131000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '21000000',
#   'paymentsForRepurchaseOfCommonStock': '0',
#   'paymentsForRepurchaseOfEquity': '0',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1467000000',
#   'dividendPayoutCommonStock': '1467000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '192000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '0',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '1325000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '1325000000'},
#  {'fiscalDateEnding': '2021-03-31',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '4914000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1672000000',
#   'capitalExpenditures': '494000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': '138000000',
#   'profitLoss': '955000000',
#   'cashflowFromInvestment': '-2000000000',
#   'cashflowFromFinancing': '-5783000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '-89000000',
#   'paymentsForRepurchaseOfCommonStock': '0',
#   'paymentsForRepurchaseOfEquity': '0',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1457000000',
#   'dividendPayoutCommonStock': '1457000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '51000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '0',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '-2869000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '955000000'},
#  {'fiscalDateEnding': '2020-12-31',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '5860000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1699000000',
#   'capitalExpenditures': '678000000',
#   'changeInReceivables': '5297000000',
#   'changeInInventory': '-209000000',
#   'profitLoss': '1356000000',
#   'cashflowFromInvestment': '-558000000',
#   'cashflowFromFinancing': '-6293000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '-386000000',
#   'paymentsForRepurchaseOfCommonStock': '0',
#   'paymentsForRepurchaseOfEquity': '0',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1454000000',
#   'dividendPayoutCommonStock': '1454000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '167000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '0',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '-4000000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '1356000000'},
#  {'fiscalDateEnding': '2020-09-30',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '4285000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1683000000',
#   'capitalExpenditures': '725000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': '-209000000',
#   'profitLoss': '1698000000',
#   'cashflowFromInvestment': '-332000000',
#   'cashflowFromFinancing': '-1689000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '-18000000',
#   'paymentsForRepurchaseOfCommonStock': '0',
#   'paymentsForRepurchaseOfEquity': '0',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1453000000',
#   'dividendPayoutCommonStock': '1453000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '147000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '0',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '1698000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '1698000000'},
#  {'fiscalDateEnding': '2020-06-30',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '3576000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1679000000',
#   'capitalExpenditures': '585000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': '-209000000',
#   'profitLoss': '1361000000',
#   'cashflowFromInvestment': '-1236000000',
#   'cashflowFromFinancing': '-1624000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '-1035000000',
#   'paymentsForRepurchaseOfCommonStock': '0',
#   'paymentsForRepurchaseOfEquity': '0',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1450000000',
#   'dividendPayoutCommonStock': '1450000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '4135000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '0',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '1361000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '1361000000'},
#  {'fiscalDateEnding': '2020-03-31',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '4476000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1634000000',
#   'capitalExpenditures': '630000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': '-209000000',
#   'profitLoss': '1175000000',
#   'cashflowFromInvestment': '-902000000',
#   'cashflowFromFinancing': '-115000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '586000000',
#   'paymentsForRepurchaseOfCommonStock': '0',
#   'paymentsForRepurchaseOfEquity': '0',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1440000000',
#   'dividendPayoutCommonStock': '1440000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '6055000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '0',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '3459000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '1175000000'},
#  {'fiscalDateEnding': '2019-12-31',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '3451000000',
#   'paymentsForOperatingActivities': '2073000000',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1650000000',
#   'capitalExpenditures': '576000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': '67000000',
#   'profitLoss': '3670000000',
#   'cashflowFromInvestment': '128000000',
#   'cashflowFromFinancing': '-5675000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '-457000000',
#   'paymentsForRepurchaseOfCommonStock': '0',
#   'paymentsForRepurchaseOfEquity': '0',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1438000000',
#   'dividendPayoutCommonStock': '1438000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '329000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '0',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '-2096000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '3670000000'},
#  {'fiscalDateEnding': '2019-09-30',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '3619000000',
#   'paymentsForOperatingActivities': '395000000',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1669000000',
#   'capitalExpenditures': '588000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': '67000000',
#   'profitLoss': '1672000000',
#   'cashflowFromInvestment': '-30373000000',
#   'cashflowFromFinancing': '-8177000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '-6733000000',
#   'paymentsForRepurchaseOfCommonStock': '125000000',
#   'paymentsForRepurchaseOfEquity': '125000000',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1436000000',
#   'dividendPayoutCommonStock': '1436000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '247000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '-125000000',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '1672000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '1672000000'},
#  {'fiscalDateEnding': '2019-06-30',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '2941000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '307000000',
#   'capitalExpenditures': '583000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': '67000000',
#   'profitLoss': '2498000000',
#   'cashflowFromInvestment': '4162000000',
#   'cashflowFromFinancing': '21031000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '4572000000',
#   'paymentsForRepurchaseOfCommonStock': '316000000',
#   'paymentsForRepurchaseOfEquity': '316000000',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1436000000',
#   'dividendPayoutCommonStock': '1436000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '25270000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '-316000000',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '2498000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '2498000000'},
#  {'fiscalDateEnding': '2019-03-31',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '4759000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1446000000',
#   'capitalExpenditures': '539000000',
#   'changeInReceivables': 'None',
#   'changeInInventory': '67000000',
#   'profitLoss': '1591000000',
#   'cashflowFromInvestment': '-853000000',
#   'cashflowFromFinancing': '1863000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '21000000',
#   'paymentsForRepurchaseOfCommonStock': '920000000',
#   'paymentsForRepurchaseOfEquity': '920000000',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1397000000',
#   'dividendPayoutCommonStock': '1397000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '5979000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '-920000000',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '5769000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '1591000000'},
#  {'fiscalDateEnding': '2018-12-31',
#   'reportedCurrency': 'USD',
#   'operatingCashflow': '4119000000',
#   'paymentsForOperatingActivities': 'None',
#   'proceedsFromOperatingActivities': 'None',
#   'changeInOperatingLiabilities': 'None',
#   'changeInOperatingAssets': 'None',
#   'depreciationDepletionAndAmortization': '1112000000',
#   'capitalExpenditures': '782000000',
#   'changeInReceivables': '1006000000',
#   'changeInInventory': '-127000000',
#   'profitLoss': '1951000000',
#   'cashflowFromInvestment': '455000000',
#   'cashflowFromFinancing': '-4605000000',
#   'proceedsFromRepaymentsOfShortTermDebt': '965000000',
#   'paymentsForRepurchaseOfCommonStock': '2050000000',
#   'paymentsForRepurchaseOfEquity': '2050000000',
#   'paymentsForRepurchaseOfPreferredStock': 'None',
#   'dividendPayout': '1416000000',
#   'dividendPayoutCommonStock': '1416000000',
#   'dividendPayoutPreferredStock': 'None',
#   'proceedsFromIssuanceOfCommonStock': 'None',
#   'proceedsFromIssuanceOfLongTermDebtAndCapitalSecuritiesNet': '2177000000',
#   'proceedsFromIssuanceOfPreferredStock': 'None',
#   'proceedsFromRepurchaseOfEquity': '-2050000000',
#   'proceedsFromSaleOfTreasuryStock': 'None',
#   'changeInCashAndCashEquivalents': '-31000000',
#   'changeInExchangeRate': 'None',
#   'netIncome': '1951000000'}]

# %%
dividends =  [ (x['fiscalDateEnding'],float(x['dividendPayout'] )) for x in dividends]
dividends
# Out:
# [('2023-09-30', 1515000000.0),
#  ('2023-06-30', 1510000000.0),
#  ('2023-03-31', 1497000000.0),
#  ('2022-12-31', 1494000000.0),
#  ('2022-09-30', 1491000000.0),
#  ('2022-06-30', 1488000000.0),
#  ('2022-03-31', 1475000000.0),
#  ('2021-12-31', 1474000000.0),
#  ('2021-09-30', 1471000000.0),
#  ('2021-06-30', 1467000000.0),
#  ('2021-03-31', 1457000000.0),
#  ('2020-12-31', 1454000000.0),
#  ('2020-09-30', 1453000000.0),
#  ('2020-06-30', 1450000000.0),
#  ('2020-03-31', 1440000000.0),
#  ('2019-12-31', 1438000000.0),
#  ('2019-09-30', 1436000000.0),
#  ('2019-06-30', 1436000000.0),
#  ('2019-03-31', 1397000000.0),
#  ('2018-12-31', 1416000000.0)]

# %%
beta = float(overview["Beta"])
roe = float(overview["ReturnOnEquityTTM"])
eps = float(overview["EPS"])
divps = float(overview["DividendPerShare"])
payout_ratio = divps/eps
div_growth_rate = roe * (1 - payout_ratio)
market_return = 0.11
prev_close = float(daily_stock_prices['Time Series (Daily)'][next(iter(daily_stock_prices['Time Series (Daily)']))].get('4. close'))

risk_free_rate = prev_close * 0.01

cost_of_equity = risk_free_rate + beta * (market_return - risk_free_rate)
#############

# %%
from pyspark import SparkContext, SparkConf
from datetime import datetime, timedelta

# Initialize Spark
conf = SparkConf().setAppName("Example").setMaster("local")
sc = SparkContext(conf=conf)

# %%
# Function to calculate present value (PV) factor
def calculate_pv_factor(row):
    fiscal_date_ending = datetime.strptime(row[0], "%Y-%m-%d")
    pv_factor = (fiscal_date_ending + timedelta(days=365) - datetime.now()).days / 365.0
    return (row[0], row[1], pv_factor)

rdd = sc.parallelize(dividends)

# Apply the transformation to the RDD
transformed_rdd = rdd.map(calculate_pv_factor)

# Function to calculate dividend growth
def calculate_dividend_growth(row):
    if row[1] != 0:
        dividend_growth = row[1] * (1 + 0.46045880000000006) / ((1 + row[2]) ** 2)
        return (row[0], row[1], row[2], dividend_growth)
    else:
        return (row[0], row[1], row[2], 0.0)

# Apply the transformation to the transformed RDD
dividend_growth = transformed_rdd.map(calculate_dividend_growth)

# %%
# Filter out zero dividends
filtered_rdd = transformed_rdd.filter(lambda row: row[1] != 0)
# Collect and print the result
# result_list = result_rdd.collect()
# for row in result_list:
#     print(row)

# %%
# Calculate present value of dividends
pv_divs = filtered_rdd.map(lambda row: row[1] / (1 + cost_of_equity) ** row[2]).sum()

# %%
# Calculate terminal value
last_row = filtered_rdd.reduce(lambda x, y: y)

last_row[2]
# Out:
# -3.96986301369863

# %%
terminal_value = (last_row[2] * (1 + div_growth_rate) / (cost_of_equity - div_growth_rate)) / (1 + cost_of_equity) ** last_row[2]

{"pv_divs": pv_divs, "terminal_value": terminal_value}
# Out:
# {'pv_divs': 61240588122.84652, 'terminal_value': -45.34180401051845}

# %%
result = multi_ddm(spark, ticker='swk', discount_rate=cost_of_equity, div_growth_rate=div_growth_rate)
print(result)

# %%
from pyspark import SparkContext,SparkSession
from datetime import datetime, timedelta

daily_stock_prices = read_json_file("daily_adjusted_full_IBM.json")

dividends_raw = read_json_file("cash_flow_IBM.json")["quarterlyReports"]

dividends =  [ (x['fiscalDateEnding'],float(x['dividendPayout'] )) for x in dividends_raw]

div_df = pd.DataFrame(dividends)
dividends_estimate = div_df[1].mode()*4

beta = float(overview["Beta"])
roe = float(overview["ReturnOnEquityTTM"])
eps = float(overview["EPS"])
divps = float(overview["DividendPerShare"])
payout_ratio = divps/eps
div_growth_rate = roe * (1 - payout_ratio)
market_return = 0.11
prev_close = float(daily_stock_prices['Time Series (Daily)'][next(iter(daily_stock_prices['Time Series (Daily)']))].get('4. close'))

risk_free_rate = prev_close * 0.01

cost_of_equity = risk_free_rate + beta * (market_return - risk_free_rate)

def calculate_pv_factor(row):
    fiscal_date_ending = datetime.strptime(row[0], "%Y-%m-%d")
    pv_factor = (fiscal_date_ending + timedelta(days=365) - datetime.now()).days / 365.0
    return (row[0], row[1], pv_factor)

def calculate_dividend_growth(row, growth_rate):
    if row[1] != 0:
        dividend_growth = row[1] * (1 + growth_rate * row[2])
        return (row[0], row[1], row[2], dividend_growth)
    else:
        return (row[0], row[1], row[2], 0.0)

def multi_ddm(row):
  '''
  Model used to predict the value of a stock given future dividend payments.
  
  discount_rate can be set as the cost of equity.

  div_growth_rate standard input is a company's ROE multiplied by the company's retention ratio.

  Time frames: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max. **Note that if the time frame is changed from the default then the
  num_future_dividends parameter also needs to be changed. For exampe if time_frame = '2y', then set the num_future_dividends to 8.

  growth_rate is an increase in the dividend amount distributed.
  '''
  time_frame='1y'
  num_future_dividends = 4
  growth_rate=3
  ticker = yf.Ticker(row[0])
  beta = ticker.info['beta']
  risk_free_rate = ticker.get_info()['previousClose']*.01
  market_return = .11

  discount_rate = risk_free_rate + beta *(market_return-risk_free_rate)


  div_growth_rate = stanley_bd.info['returnOnEquity'] * (1-stanley_bd.get_info()['payoutRatio'])

  div_per_share = stanley_bd.get_info()['previousClose'] * stanley_bd.info['dividendYield']
    
  dividend_history = ticker.history(period=time_frame)['Dividends'][ticker.history(period=time_frame)['Dividends'] != 0]
  dividend_estimate = [dividend_history.mode().iloc[-1]]*num_future_dividends
  pv_factor = [( (date + datetime.timedelta(days=365)).to_pydatetime(pytz.UTC) - datetime.datetime.now(pytz.UTC)).days/365 for date in  dividend_history.index]
  dividend_growth = [dividend * 1+(growth_rate*factor) for dividend,factor in zip(dividend_estimate,pv_factor)]
  pv_divs = sum([dividend/(1+discount_rate)**factor for factor,dividend in zip(pv_factor,dividend_growth)])
  terminal_value = (dividend_growth[-1] * (1+div_growth_rate)/(discount_rate - div_growth_rate))/(1+discount_rate)**pv_factor[-1]
  ddm = pv_divs+terminal_value

  return (row[0],ddm)



# Example usage
if __name__ == "__main__":
    # Initialize SparkContext

    sc = SparkContext(appName="DDMVModel")
    

    # Sample data for demonstration
    data = dividends
    # Example parameters
    discount_rate = cost_of_equity
    growth_rate = 0.0

    # Calculate DDM value using RDD
    ddm_result = multi_ddm_rdd(sc, data, discount_rate, div_growth_rate, growth_rate)

    print("DDM Value:")
    print(ddm_result)

    # Stop the SparkContext
    sc.stop()
# Out:
# DDM Value:
# 77413436973.63766

# %%
import requests
import csv
import pandas as pd
from pyspark import SparkContext

CSV_URL = 'https://www.alphavantage.co/query?function=LISTING_STATUS&status=active&apikey=SBDZS38E0OSX9D8S'

with requests.Session() as s:
    download = s.get(CSV_URL)
    decoded_content = download.content.decode('utf-8')
    cr = csv.reader(decoded_content.splitlines(), delimiter=',')
    my_list = list(cr)

    stock_symbols_df = pd.DataFrame(my_list[1:],columns=my_list[0])
    # for row in my_list:
    #     print(row)
stocks_df = stock_symbols_df[stock_symbols_df['assetType']=='Stock']['symbol']

sc = SparkContext(appName="DDMVModel")
sc_df = sc.parallelize(stocks_df)

# %%
import yfinance as yf

def multi_ddm(row):
  '''
  Model used to predict the value of a stock given future dividend payments.
  
  discount_rate can be set as the cost of equity.

  div_growth_rate standard input is a company's ROE multiplied by the company's retention ratio.

  Time frames: 1d,5d,1mo,3mo,6mo,1y,2y,5y,10y,ytd,max. **Note that if the time frame is changed from the default then the
  num_future_dividends parameter also needs to be changed. For exampe if time_frame = '2y', then set the num_future_dividends to 8.

  growth_rate is an increase in the dividend amount distributed.
  '''
  time_frame='1y'
  num_future_dividends = 4
  growth_rate=3
  ticker = yf.Ticker(row[0])
  beta = ticker.info['beta']
  risk_free_rate = ticker.get_info()['previousClose']*.01
  market_return = .11

  discount_rate = risk_free_rate + beta *(market_return-risk_free_rate)


  div_growth_rate = ticker.info['returnOnEquity'] * (1-ticker.get_info()['payoutRatio'])

  div_per_share = ticker.get_info()['previousClose'] * ticker.info['dividendYield']
    
  dividend_history = ticker.history(period=time_frame)['Dividends'][ticker.history(period=time_frame)['Dividends'] != 0]
  dividend_estimate = [dividend_history.mode().iloc[-1]]*num_future_dividends
  pv_factor = [( (date + datetime.timedelta(days=365)).to_pydatetime(pytz.UTC) - datetime.datetime.now(pytz.UTC)).days/365 for date in  dividend_history.index]
  dividend_growth = [dividend * 1+(growth_rate*factor) for dividend,factor in zip(dividend_estimate,pv_factor)]
  pv_divs = sum([dividend/(1+discount_rate)**factor for factor,dividend in zip(pv_factor,dividend_growth)])
  terminal_value = (dividend_growth[-1] * (1+div_growth_rate)/(discount_rate - div_growth_rate))/(1+discount_rate)**pv_factor[-1]
  ddm = pv_divs+terminal_value

  return (row[0],ddm)

ddm_df = sc_df.map(multi_ddm)
